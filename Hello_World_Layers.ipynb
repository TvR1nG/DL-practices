# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

layer_0 = keras.layers.Dense(units=1, input_shape=[1])
#在keras中，使用Dense来定义神经元
#unit表示只有一个神经元，shape表示输入形状

model = tf.keras.Sequential([layer_0])

model.compile(optimizer='sgd', loss='mean_squared_error')
#优化器sgd是随机梯度下降，loss function是均方根误差

xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)
#训练在fit命令里进行，500次训练循环

print(model.predict([10.0]))

print("Layer variables look like this: {}".format(layer_0.get_weights()))
# Out:
# Train on 6 samples
# Epoch 1/500
# 6/6 [==============================] - 0s 45ms/sample - loss: 7.8131
# Epoch 2/500
# 6/6 [==============================] - 0s 499us/sample - loss: 6.3431
# Epoch 3/500
# 6/6 [==============================] - 0s 498us/sample - loss: 5.1827
# Epoch 4/500
# 6/6 [==============================] - 0s 665us/sample - loss: 4.2657
# Epoch 5/500
# 6/6 [==============================] - 0s 499us/sample - loss: 3.5404
# Epoch 6/500
# 6/6 [==============================] - 0s 332us/sample - loss: 2.9660
# Epoch 7/500
# 6/6 [==============================] - 0s 498us/sample - loss: 2.5104
# Epoch 8/500
# 6/6 [==============================] - 0s 665us/sample - loss: 2.1483
# Epoch 9/500
# 6/6 [==============================] - 0s 333us/sample - loss: 1.8598
# Epoch 10/500
# 6/6 [==============================] - 0s 665us/sample - loss: 1.6294
# Epoch 11/500
# 6/6 [==============================] - 0s 332us/sample - loss: 1.4447
# Epoch 12/500
# ...
